# %%
from nlp.preprocessing import basic_preprocess
from nlp.embeddings import MultilingualEmbedder
import pandas as pd

df = pd.read_csv("data/raw/even_more_articles_normalized.csv", sep=";")

df["text_for_embedding"] = (
    df["title"] + ". " + df["content"]
).apply(basic_preprocess)

embedder = MultilingualEmbedder()
embeddings = embedder.encode(df["text_for_embedding"].tolist())

df["embedding"] = embeddings.tolist()
# Out:
# Batches:   0%|          | 0/218 [00:00<?, ?it/s]

# %%
df
# Out:
#         source                                                url  \
# 0       Xataka  https://www.xataka.com/empresas-y-economia/mas...
# 1       Xataka  https://www.xataka.com/robotica-e-ia/plan-indu...
# 2       Xataka  https://www.xataka.com/robotica-e-ia/no-coca-c...
# 3       Xataka  https://www.xataka.com/componentes/huawei-kunp...
# 4       Xataka  https://www.xataka.com/empresas-y-economia/rea...
# ...        ...                                                ...
# 6942  Wired ES  https://es.wired.com/articulos/deepseek-r1-pue...
# 6943  Wired ES  https://es.wired.com/articulos/demanda-energet...
# 6944  Wired ES  https://es.wired.com/articulos/el-36-por-cient...
# 6945  Wired ES  https://es.wired.com/articulos/x-lanza-oficial...
# 6946  Wired ES  https://es.wired.com/articulos/rabbit-r1-arras...
#
#                                                   title  \
# 0     MásMóvil compra Sofiathinks, la startup sevill...
# 1     El plan industrial de EEUU se desmorona porque...
# 2     No, Coca-Cola no está usando inteligencia arti...
# 3     Huawei Kunpeng 920: así es el SoC de 7 nm con ...
# 4     Realme más allá del smartphone: así quieren co...
# ...                                                 ...
# 6942  El futuro es la eficiencia: DeepSeek R1 puede ...
# 6943  La demanda energética de la IA está fuera de c...
# 6944  El 36% de las personas se sienten cómodas leye...
# 6945  X lanza oficialmente Grok 3, su nuevo modelo d...
# 6946  El Rabbit R1 que arrasó en las ferias tecnológ...
#
#                                                 content  \
# 0     Desarrollar hardware en España no es tan habit...
# 1     La IA generativa es tontísima. Es la opinión d...
# 2     La fiebre por la inteligencia artificial está ...
# 3     Huawei no se anda con «chiquitas»: según la ma...
# 4     Realme se ha convertido rápidamente en una mar...
# ...                                                 ...
# 6942  La inteligencia artificial, o ya popularmente ...
# 6943  En estos momentos, es imposible ignorar la int...
# 6944  El uso de la inteligencia artificial (IA) en l...
# 6945  Tras muchos meses de espera, xAI, la empresa d...
# 6946  El camino que conducía a la sede de Rabbit est...
#
#                    scraping_date  content_length  word_count language  \
# 0     2026-01-27 22:20:23.210903            2311         361       es
# 1     2026-01-27 22:20:23.439998            5739         983       es
# 2     2026-01-27 22:20:24.200502            2926         489       es
# 3     2026-01-27 22:20:24.502001            3463         568       es
# 4     2026-01-27 22:20:24.722319            3769         614       es
# ...                          ...             ...         ...      ...
# 6942  2026-01-28 00:18:13.756831            6678        1101       es
# 6943  2026-01-28 00:18:14.107712           10412        1670       es
# 6944  2026-01-28 00:18:14.539258            5331         859       es
# 6945  2026-01-28 00:18:15.263931            3882         657       es
# 6946  2026-01-28 00:18:17.575284            9142        1569       es
#
#       is_valid                                 text_for_embedding  \
# 0         True  másmóvil compra sofiathinks, la startup sevill...
# 1         True  el plan industrial de eeuu se desmorona porque...
# 2         True  no, coca-cola no está usando inteligencia arti...
# 3         True  huawei kunpeng 920: así es el soc de 7 nm con ...
# 4         True  realme más allá del smartphone: así quieren co...
# ...        ...                                                ...
# 6942      True  el futuro es la eficiencia: deepseek r1 puede ...
# 6943      True  la demanda energética de la ia está fuera de c...
# 6944      True  el 36% de las personas se sienten cómodas leye...
# 6945      True  x lanza oficialmente grok 3, su nuevo modelo d...
# 6946      True  el rabbit r1 que arrasó en las ferias tecnológ...
#
#                                               embedding
# 0     [-0.07274366915225983, 0.0015239028725773096, ...
# 1     [-0.02412223257124424, -0.0039038704708218575,...
# 2     [-0.06929256021976471, -0.025205407291650772, ...
# 3     [-0.020797504112124443, 0.033911801874637604, ...
# 4     [-0.023625032976269722, 0.06192409619688988, -...
# ...                                                 ...
# 6942  [-0.03478584438562393, 0.04077095538377762, -0...
# 6943  [-0.07210040092468262, -0.01855670101940632, 0...
# 6944  [0.032202500849962234, -0.08944417536258698, -...
# 6945  [-0.11077526956796646, -0.03666113689541817, -...
# 6946  [-0.03756772354245186, -0.0057035163044929504,...
#
# [6947 rows x 11 columns]

# %% [markdown]
# ## TF-IDF

# %%
# !pip install spacy
# !python -m spacy download es_core_news_sm
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\angel\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\angel\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\angel\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\angel\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\angel\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\angel\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\angel\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\angel\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\angel\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\angel\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\angel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\angel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\angel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\angel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\angel\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\angel\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in c:\users\angel\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\angel\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 1.6 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/14.2 MB 1.4 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/14.2 MB 1.4 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.6/14.2 MB 1.6 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/14.2 MB 1.7 MB/s eta 0:00:08
#    ------ --------------------------------- 2.4/14.2 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.6/14.2 MB 1.7 MB/s eta 0:00:07
#    --------- ------------------------------ 3.4/14.2 MB 1.9 MB/s eta 0:00:06
#    ------------ --------------------------- 4.5/14.2 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.2/14.2 MB 2.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.3/14.2 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 7.1/14.2 MB 2.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.1/14.2 MB 2.9 MB/s eta 0:00:03
#    ------------------------- -------------- 8.9/14.2 MB 3.0 MB/s eta 0:00:02
#    --------------------------- ------------ 9.7/14.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------------ --------- 10.7/14.2 MB 3.2 MB/s eta 0:00:02
#    ------------------------------- -------- 11.3/14.2 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 12.1/14.2 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.6/14.2 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 13.4/14.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 3.2 MB/s eta 0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl (25 kB)
# Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl (117 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl (653 kB)
#    ---------------------------------------- 0.0/653.1 kB ? eta -:--:--
#    ---------------------------------------- 653.1/653.1 kB 5.1 MB/s eta 0:00:00
# Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.2 MB/s eta 0:00:00
# Downloading blis-1.3.3-cp313-cp313-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.2 MB 3.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.2 MB 4.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.2 MB 3.3 MB/s eta 0:00:02
#    --------------- ------------------------ 2.4/6.2 MB 3.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.6/6.2 MB 3.1 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.2 MB 2.5 MB/s eta 0:00:02
#    -------------------- ------------------- 3.1/6.2 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.4/6.2 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.2 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 3.9/6.2 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 4.2/6.2 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.2 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 2.2 MB/s eta 0:00:00
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, cymem, cloudpathlib, catalogue, blis, typer-slim, srsly, preshed, confection, weasel, thinc, spacy
#
#    ------- --------------------------------  3/16 [smart-open]
#    --------------- ------------------------  6/16 [cloudpathlib]
#    -------------------- -------------------  8/16 [blis]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    ------------------------- -------------- 10/16 [srsly]
#    -------------------------------- ------- 13/16 [weasel]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ----------------------------------- ---- 14/16 [thinc]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ------------------------------------- -- 15/16 [spacy]
#    ---------------------------------------- 16/16 [spacy]
#
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.12 smart-open-7.5.0 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 typer-slim-0.21.1 wasabi-1.1.3 weasel-0.4.3
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.9 MB 4.1 MB/s eta 0:00:03
#      --- ------------------------------------ 1.0/12.9 MB 3.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/12.9 MB 2.8 MB/s eta 0:00:05
#      ------ --------------------------------- 2.1/12.9 MB 2.8 MB/s eta 0:00:04
#      -------- ------------------------------- 2.9/12.9 MB 3.0 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.7/12.9 MB 3.1 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.9 MB 3.1 MB/s eta 0:00:03
#      ------------- -------------------------- 4.5/12.9 MB 2.9 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.9 MB 2.9 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.2/12.9 MB 2.6 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.9 MB 2.7 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.9 MB 2.8 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.3/12.9 MB 2.9 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.9 MB 2.9 MB/s eta 0:00:02
#      -------------------------- ------------- 8.7/12.9 MB 2.9 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.9 MB 3.0 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.9 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.9 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.9 MB 3.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.9 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 2.1 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.6/12.8 MB 2.7 MB/s eta 0:00:05
#      ------ --------------------------------- 2.1/12.8 MB 2.9 MB/s eta 0:00:04
#      -------- ------------------------------- 2.6/12.8 MB 2.8 MB/s eta 0:00:04
#      --------- ------------------------------ 3.1/12.8 MB 2.9 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.7/12.8 MB 2.7 MB/s eta 0:00:04
#      ------------ --------------------------- 3.9/12.8 MB 2.6 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.8 MB 2.6 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.7 MB/s eta 0:00:03
#      ------------------- -------------------- 6.3/12.8 MB 2.9 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 2.9 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.6/12.8 MB 2.9 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 3.0 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 3.0 MB/s eta 0:00:02
#      ------------------------------ --------- 9.7/12.8 MB 3.1 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 3.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from nlp.cleaning_tfidf import clean_for_tfidf, compute_tfidf

df["text_tfidf"] = df.apply(
    lambda row: clean_for_tfidf(row["content"], row["language"]),
    axis=1
)

X_tfidf, tfidf_vectorizer = compute_tfidf(df["text_tfidf"])

# %% [markdown]
# ## Embeddings

# %%
import numpy as np

embeddings = np.vstack(df["embedding"].values)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(embeddings)

# %%
SIM_THRESHOLD = 0.95

duplicates = []

n = similarity_matrix.shape[0]

for i in range(n):
    for j in range(i + 1, n):
        if similarity_matrix[i, j] > SIM_THRESHOLD:
            duplicates.append((i, j, similarity_matrix[i, j]))

# %%
duplicates
# Out:
# [(1285, 1293, np.float64(0.9583771930167495)),
#  (1493, 1497, np.float64(0.9565090439202213)),
#  (1580, 1587, np.float64(0.9616493347496956)),
#  (1587, 1645, np.float64(0.9502489032414585)),
#  (1617, 1621, np.float64(0.9773572978682494)),
#  (1617, 1979, np.float64(0.9623197524210518)),
#  (1617, 2786, np.float64(0.9822738700819165)),
#  (1621, 1979, np.float64(0.9576259540740252)),
#  (1621, 2786, np.float64(0.9682553909988338)),
#  (1664, 3080, np.float64(0.9560258275225566)),
#  (1979, 2786, np.float64(0.9601944623451493)),
#  (2046, 2067, np.float64(0.9564113432836112)),
#  (2659, 3168, np.float64(0.9589982991518147)),
#  (2705, 2915, np.float64(0.9620202676221505)),
#  (2744, 2768, np.float64(0.9578361255565321)),
#  (3505, 3508, np.float64(0.9625775818241643)),
#  (3505, 3512, np.float64(0.9641539790053835)),
#  (3505, 3534, np.float64(0.9556861568628234)),
#  (3508, 3512, np.float64(0.9825961075800594)),
#  (3508, 3516, np.float64(0.9670622477561306)),
#  (3508, 3534, np.float64(0.9539484339492281)),
#  (3508, 3546, np.float64(0.9539427942079804)),
#  (3512, 3516, np.float64(0.9636470096944527)),
#  (3512, 3534, np.float64(0.9604437242971067)),
#  (3512, 3546, np.float64(0.9563099589332138)),
#  (3516, 3534, np.float64(0.9627780721892576)),
#  (3516, 3546, np.float64(0.9638202700032623)),
#  (3634, 3948, np.float64(0.9636674258027871)),
#  (3634, 4108, np.float64(0.9780780412689114)),
#  (3656, 3966, np.float64(0.9710007339236978)),
#  (3748, 3805, np.float64(0.953314876970496)),
#  (3925, 3944, np.float64(0.9757818961096669)),
#  (3957, 3961, np.float64(0.9662528447066489)),
#  (3959, 3962, np.float64(0.9502993337524648)),
#  (3959, 3963, np.float64(0.9704653693163435)),
#  (3962, 3963, np.float64(0.9642825465929191)),
#  (4380, 4660, np.float64(0.9510738141886467)),
#  (4505, 5082, np.float64(0.959105697077064)),
#  (4736, 4943, np.float64(0.9603476946344913)),
#  (4741, 4767, np.float64(0.9599232811184961)),
#  (4767, 5364, np.float64(0.9503101747360431)),
#  (4829, 5607, np.float64(0.980299808544607)),
#  (4881, 5610, np.float64(0.9570052619355034)),
#  (5153, 5585, np.float64(0.9656127509955347)),
#  (5222, 5230, np.float64(0.9509027817015232)),
#  (5684, 5705, np.float64(0.9636763213373563)),
#  (5815, 6636, np.float64(0.9926182908480049))]

# %%
pd.set_option('display.max_colwidth', 400)
df.iloc[5815:5816]
# Out:
#         source  \
# 5815  Wired ES
#
#                                                                                                   url  \
# 5815  https://es.wired.com/articulos/el-nuevo-estandar-profesional-aprender-pensar-y-construir-con-ai
#
#                                                                    title  \
# 5815  El nuevo estándar profesional: aprender, pensar y construir con IA
#
#                                                                                                                                                                                                                                                                                                                                                                                                               content  \
# 5815  Hace unos días, Tobi Lütke, CEO de Shopify, envió un memo a todo su equipo. No fue un anuncio más. Fue una especie de manifiesto para la era de la inteligencia artificial, un llamado claro, directo y –para quien quiera leer entre líneas– inevitable: usar IA no es opcional, es el nuevo estándar. Tobi no habla de IA como una herramienta técnica, sino como una extensión del pensamiento. Un though...
#
#                    scraping_date  content_length  word_count language  \
# 5815  2026-01-27 23:59:36.084658            3898         649       es
#
#       is_valid  \
# 5815      True
#
#                                                                                                                                                                                                                                                                                                                                                                                                    text_for_embedding  \
# 5815  el nuevo estándar profesional: aprender, pensar y construir con ia. hace unos días, tobi lütke, ceo de shopify, envió un memo a todo su equipo. no fue un anuncio más. fue una especie de manifiesto para la era de la inteligencia artificial, un llamado claro, directo y –para quien quiera leer entre líneas– inevitable: usar ia no es opcional, es el nuevo estándar. tobi no habla de ia como una her...
#
#                                                                                                                                                                                                                                                                                                                                                                                                             embedding  \
# 5815  [-0.037302978336811066, 0.0007519237697124481, -0.06110101193189621, -0.03367425501346588, -0.021479792892932892, 0.07924506813287735, -0.03287385404109955, -0.007805817760527134, 0.03979293629527092, 0.011570625007152557, 0.035594575107097626, 0.07757695764303207, 0.030370738357305527, 0.0005514141521416605, -0.003065405646339059, -0.04600278660655022, 0.0326765812933445, 0.018769480288028717...
#
#                                                                                                                                                                                                                                                                                                                                                                                                            text_tfidf
# 5815  tobi lütke ceo shopify enviar memo equipo anuncio especie manifiesto inteligencia artificial llamado directo querer leer línea inevitable ia opcional estándar tobi ia herramienta técnico extensión pensamiento thought partner deep researcher crítico tutor par programador frase clave resaltar fuerza ai acts as multiplier inteligencia artificial simplemente eficiente tecnología multiplicadoro per...

# %%
df.iloc[6636:6637]
# Out:
#         source  \
# 6636  Wired ES
#
#                                                                                                   url  \
# 6636  https://es.wired.com/articulos/el-nuevo-estandar-profesional-aprender-pensar-y-construir-con-ia
#
#                                                                    title  \
# 6636  El nuevo estándar profesional: aprender, pensar y construir con IA
#
#                                                                                                                                                                                                                                                                                                                                                                                                               content  \
# 6636  Hace unos días, Tobi Lütke, CEO de Shopify, envió un memo a todo su equipo. No fue un anuncio más. Fue una especie de manifiesto para la era de la inteligencia artificial, un llamado claro, directo y –para quien quiera leer entre líneas– inevitable: usar IA no es opcional, es el nuevo estándar. Tobi no habla de IA como una herramienta técnica, sino como una extensión del pensamiento. Un “ thou...
#
#                    scraping_date  content_length  word_count language  \
# 6636  2026-01-28 00:13:14.224868            4164         699       es
#
#       is_valid  \
# 6636      True
#
#                                                                                                                                                                                                                                                                                                                                                                                                    text_for_embedding  \
# 6636  el nuevo estándar profesional: aprender, pensar y construir con ia. hace unos días, tobi lütke, ceo de shopify, envió un memo a todo su equipo. no fue un anuncio más. fue una especie de manifiesto para la era de la inteligencia artificial, un llamado claro, directo y –para quien quiera leer entre líneas– inevitable: usar ia no es opcional, es el nuevo estándar. tobi no habla de ia como una her...
#
#                                                                                                                                                                                                                                                                                                                                                                                                             embedding  \
# 6636  [-0.03542952239513397, 0.005845795385539532, -0.07028206437826157, -0.03629961982369423, -0.02481769770383835, 0.07608772069215775, -0.02665936015546322, -0.014837047085165977, 0.04117237403988838, 0.016544749960303307, 0.048402149230241776, 0.07901087403297424, 0.029446715489029884, 0.00874806847423315, -0.005813340190798044, -0.04374442994594574, 0.02660360187292099, 0.015516841784119606, -0...
#
#                                                                                                                                                                                                                                                                                                                                                                                                            text_tfidf
# 6636  tobi lütke ceo shopify enviar memo equipo anuncio especie manifiesto inteligencia artificial llamado directo querer leer línea inevitable ia opcional estándar tobi ia herramienta técnico extensión pensamiento thought partner deep researcher crítico tutor par programador frase clave resaltar fuerza ai acts as multiplier inteligencia artificial simplemente eficiente tecnología multiplicadoro per...

# %%
to_drop = set()

for i, j, sim in duplicates:
    if df.loc[i, "word_count"] >= df.loc[j, "word_count"]:
        to_drop.add(j)
    else:
        to_drop.add(i)

df_curated = df.drop(index=to_drop).reset_index(drop=True)

# %%
df_curated["semantic_score"] = cosine_similarity(
    np.vstack(df_curated["embedding"].values)
).mean(axis=1)

df_top = df_curated.sort_values(
    "semantic_score", ascending=False
).head(10)

# %%
df_top[:3]
# Out:
#           source  \
# 965   TechCrunch
# 1089  TechCrunch
# 1880  TechCrunch
#
#                                                                                                                     url  \
# 965                               https://techcrunch.com/2023/01/25/dont-be-sucked-in-by-ais-head-spinning-hype-cycles/
# 1089  https://techcrunch.com/2022/08/12/a-startup-wants-to-democratize-the-tech-behind-dall-e-2-consequences-be-damned/
# 1880                        https://techcrunch.com/2021/03/17/to-solve-all-the-small-things-look-to-everyday-little-ai/
#
#                                                                         title  \
# 965                      Don’t be sucked in by AI’s head-spinning hype cycles
# 1089  This startup is setting a DALL-E 2-like AI free, consequences be damned
# 1880                To solve all the small things, look to everyday Little AI
#
#                                                                                                                                                                                                                                                                                                                                                                                                               content  \
# 965   Latest AI Amazon Apps Biotech & Health Climate Cloud Computing Commerce Crypto Enterprise EVs Fintech Fundraising Gadgets Gaming Google Government & Policy Hardware Instagram Layoffs Media & Entertainment Meta Microsoft Privacy Robotics Security Social Space Startups TikTok Transportation Venture Staff Events Startup Battlefield StrictlyVC Newsletters Podcasts Videos Partner Content TechCrunch...
# 1089  Latest AI Amazon Apps Biotech & Health Climate Cloud Computing Commerce Crypto Enterprise EVs Fintech Fundraising Gadgets Gaming Google Government & Policy Hardware Instagram Layoffs Media & Entertainment Meta Microsoft Privacy Robotics Security Social Space Startups TikTok Transportation Venture Staff Events Startup Battlefield StrictlyVC Newsletters Podcasts Videos Partner Content TechCrunch...
# 1880  Latest AI Amazon Apps Biotech & Health Climate Cloud Computing Commerce Crypto Enterprise EVs Fintech Fundraising Gadgets Gaming Google Government & Policy Hardware Instagram Layoffs Media & Entertainment Meta Microsoft Privacy Robotics Security Social Space Startups TikTok Transportation Venture Staff Events Startup Battlefield StrictlyVC Newsletters Podcasts Videos Partner Content TechCrunch...
#
#                    scraping_date  content_length  word_count language  \
# 965   2026-01-27 22:34:46.053107            8597        1469       en
# 1089  2026-01-27 22:37:09.890702           15519        2413       en
# 1880  2026-01-27 22:53:25.596510            8071        1326       en
#
#       is_valid  \
# 965       True
# 1089      True
# 1880      True
#
#                                                                                                                                                                                                                                                                                                                                                                                                    text_for_embedding  \
# 965   don’t be sucked in by ai’s head-spinning hype cycles. latest ai amazon apps biotech & health climate cloud computing commerce crypto enterprise evs fintech fundraising gadgets gaming google government & policy hardware instagram layoffs media & entertainment meta microsoft privacy robotics security social space startups tiktok transportation venture staff events startup battlefield strictlyvc ...
# 1089  this startup is setting a dall-e 2-like ai free, consequences be damned. latest ai amazon apps biotech & health climate cloud computing commerce crypto enterprise evs fintech fundraising gadgets gaming google government & policy hardware instagram layoffs media & entertainment meta microsoft privacy robotics security social space startups tiktok transportation venture staff events startup batt...
# 1880  to solve all the small things, look to everyday little ai. latest ai amazon apps biotech & health climate cloud computing commerce crypto enterprise evs fintech fundraising gadgets gaming google government & policy hardware instagram layoffs media & entertainment meta microsoft privacy robotics security social space startups tiktok transportation venture staff events startup battlefield strict...
#
#                                                                                                                                                                                                                                                                                                                                                                                                             embedding  \
# 965   [0.017832091078162193, -0.08106821030378342, 0.0025855835992842913, -0.055707644671201706, 0.016678491607308388, 0.05131446197628975, 0.012811832129955292, -0.0006794038927182555, 0.05601341649889946, 0.08199314773082733, 0.020988967269659042, -0.009115754626691341, 0.0736435204744339, 0.05227575823664665, 0.08098765462636948, -0.00859314389526844, -0.03557593747973442, -0.06781534105539322, 0...
# 1089  [-0.026582200080156326, -0.060540374368429184, -0.013119612820446491, -0.0018345908029004931, -0.006993877701461315, 0.042876236140728, -0.040214117616415024, -0.0026990347541868687, 0.059223126620054245, 0.12089245021343231, 0.03813495486974716, -0.038713160902261734, 0.07765555381774902, 0.031004564836621284, 0.09279968589544296, -0.03817423805594444, -0.030344944447278976, -0.06538052856922...
# 1880  [0.019246689975261688, -0.05965128540992737, 0.03805939108133316, -0.026886094361543655, 0.035266805440187454, 0.01532215066254139, -0.02357632853090763, 0.04394548758864403, 0.03452276065945625, 0.10495997220277786, 0.008539716713130474, -0.035238951444625854, 0.0583551824092865, 0.044702302664518356, 0.08988706767559052, -0.03521633520722389, -0.05538453906774521, -0.0629916861653328, -0.053...
#
#                                                                                                                                                                                                                                                                                                                                                                                                            text_tfidf  \
# 965   late ai amazon apps biotech health climate cloud computing commerce crypto enterprise ev fintech fundraising gadget game google government policy hardware instagram layoffs media entertainment meta microsoft privacy robotics security social space startups tiktok transportation venture staff events startup battlefield strictlyvc newsletters podcast videos partner content techcrunch brand studio...
# 1089  late ai amazon apps biotech health climate cloud computing commerce crypto enterprise ev fintech fundraising gadget game google government policy hardware instagram layoffs media entertainment meta microsoft privacy robotics security social space startups tiktok transportation venture staff events startup battlefield strictlyvc newsletters podcast videos partner content techcrunch brand studio...
# 1880  late ai amazon apps biotech health climate cloud computing commerce crypto enterprise ev fintech fundraising gadget game google government policy hardware instagram layoffs media entertainment meta microsoft privacy robotics security social space startups tiktok transportation venture staff events startup battlefield strictlyvc newsletters podcast videos partner content techcrunch brand studio...
#
#       semantic_score
# 965         0.530130
# 1089        0.527203
# 1880        0.525994

# %% [markdown]
# ## Clustering

# %%
from sklearn.cluster import KMeans, HDBSCAN

k = 5  # número de topics
kmeans = KMeans(n_clusters=k, random_state=42)
df["cluster"] = kmeans.fit_predict(embeddings)

hdb = HDBSCAN()
df["cluster2"] = hdb.fit_predict(embeddings)

# %%
a=df.groupby('cluster').size()
print(a)

b=df.groupby('cluster2').size()
print(b)
# Out:
# cluster
# 0    3714
# 1     429
# 2     925
# 3     993
# 4     886
# dtype: int64
# cluster2
# -1     4300
#  0        5
#  1        8
#  2        7
#  3        6
#  4        9
#  5        8
#  6        6
#  7       34
#  8        7
#  9        9
#  10      10
#  11      46
#  12       5
#  13       8
#  14      21
#  15       7
#  16    2069
#  17       7
#  18     375
# dtype: int64

# %%
def top_terms_per_cluster(tfidf_matrix, df, vectorizer, cluster_id, top_n=10):
    idx = df[df["cluster"] == cluster_id].index
    mean_tfidf = tfidf_matrix[idx].mean(axis=0)
    terms = vectorizer.get_feature_names_out()
    top_idx = np.argsort(mean_tfidf.A1)[::-1][:top_n]
    return [terms[i] for i in top_idx]

top_terms_per_cluster(X_tfidf, df, tfidf_vectorizer, "cluster", top_n=10)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 8
#       5     top_idx = np.argsort(mean_tfidf.A1)[::-1][:top_n]
#       6     return [terms[i] for i in top_idx]
# ----> 8 top_terms_per_cluster(X_tfidf, df, tfidf_vectorizer, "cluster", top_n=10)
#
# Cell In[13], line 3, in top_terms_per_cluster(tfidf_matrix, df, vectorizer, cluster_id, top_n)
#       1 def top_terms_per_cluster(tfidf_matrix, df, vectorizer, cluster_id, top_n=10):
#       2     idx = df[df["cluster"] == cluster_id].index
# ----> 3     mean_tfidf = tfidf_matrix[idx].mean(axis=0)
#       4     terms = vectorizer.get_feature_names_out()
#       5     top_idx = np.argsort(mean_tfidf.A1)[::-1][:top_n]
#
# File c:\Users\Angel\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1244, in _spbase.mean(self, axis, dtype, out)
#    1242 # axis = 0 or 1 now
#    1243 if axis == 0:
# -> 1244     return (inter_self * (1.0 / self.shape[0])).sum(
#    1245         axis=0, dtype=res_dtype, out=out)
#    1246 else:
#    1247     return (inter_self * (1.0 / self.shape[1])).sum(
#    1248         axis=1, dtype=res_dtype, out=out)
#
# ZeroDivisionError: float division by zero

# %%
df["length_score"] = df["content"].str.len()
df["novelty_score"] = 1 - df.index.map(lambda i: similarity_matrix[i].mean())

df["final_score"] = (
    0.5 * df["novelty_score"] +
    0.3 * (df["length_score"] / df["length_score"].max()) +
    0.2 * df["source"].isin(["OpenAI", "AWS"]).astype(int)
)

# %% [markdown]
# ## HTML

# %%
AMC_PROFILES = {
    "Data & AI": "machine learning artificial intelligence data science models",
    "IT & Cloud": "cloud infrastructure devops aws azure automation",
    "Business": "strategy innovation digital transformation business",
    "Risk & Compliance": "regulation ai ethics governance risk compliance"
}

profile_embs = embedder.encode(list(AMC_PROFILES.values()))


def assign_area(article_emb, profile_embs, areas):
    sims = cosine_similarity([article_emb], profile_embs)[0]
    return areas[np.argmax(sims)]

areas = list(AMC_PROFILES.keys())
df["area"] = [
    assign_area(e, profile_embs, areas)
    for e in embeddings
]

def generate_newsletter(df_area, area_name):
    html = f"<h1>Newsletter – {area_name}</h1><ul>"
    for _, row in df_area.sort_values("final_score", ascending=False).head(10).iterrows():
        html += f"""
        <li>
            <b>{row['title']}</b><br>
            <i>{row['source']}</i><br>
            <a href="{row['url']}">Leer más</a>
        </li>
        """
    html += "</ul>"
    return html
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
generate_newsletter(df,"Risk & Compliance")
# Out:
# '<h1>Newsletter – Risk & Compliance</h1><ul>\n        <li>\n            <b>El peligro para la terapia no es la IA: es la ausencia de comunidad</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/el-peligro-para-la-terapia-no-es-la-ia-es-la-ausencia-de-comunidad">Leer más</a>\n        </li>\n        \n        <li>\n            <b>Me fui a un retiro con tres personas (humanas) y sus parejas (de IA)</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/me-fui-a-un-retiro-con-tres-personas-humanas-y-sus-parejas-de-ia">Leer más</a>\n        </li>\n        \n        <li>\n            <b>La historia de la obsesión de Peter Thiel por el Anticristo</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/la-historia-de-la-obsesion-de-peter-thiel-por-el-anticristo">Leer más</a>\n        </li>\n        \n        <li>\n            <b>How Disney Built Star Wars, in real life</b><br>\n            <i>TechCrunch</i><br>\n            <a href="https://techcrunch.com/2019/02/27/how-disney-built-star-wars-in-real-life/">Leer más</a>\n        </li>\n        \n        <li>\n            <b>Pepe Aguilar: "La IA no me intimida. Veo con optimismo las oportunidades que ofrece para mi música y mi mensaje"</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/pepe-aguilar-la-ia-no-me-intimida-veo-con-optimismo-las-oportunidades-que-ofrece-para-mi-musica-y-mi-mensaje">Leer más</a>\n        </li>\n        \n        <li>\n            <b>Reseña del libro de Yuval Noah Harari,Nexus: Una breve historia de las redes de información desde la Edad de Piedra hasta la IA</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/resena-del-libro-de-yuval-noah-harari-nexus-una-breve-historia-de-las-redes-de-informacion-desde-la-edad-de-piedra-hasta-la-ia">Leer más</a>\n        </li>\n        \n        <li>\n            <b>¿Dónde están todos los medicamentos que la IA nos prometió?</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/donde-estan-todos-los-medicamentos-que-la-ia-nos-prometio">Leer más</a>\n        </li>\n        \n        <li>\n            <b>Los papás se enamoraron de esta escuela impulsada con IA. Resultó ser una pesadilla</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/los-papas-se-enamoraron-de-esta-escuela-impulsada-con-ia-resulto-ser-una-pesadilla">Leer más</a>\n        </li>\n        \n        <li>\n            <b>Strands Agents SDK: A technical deep dive into agent architectures and observability</b><br>\n            <i>AWS Blog</i><br>\n            <a href="https://aws.amazon.com/blogs/machine-learning/strands-agents-sdk-a-technical-deep-dive-into-agent-architectures-and-observability/">Leer más</a>\n        </li>\n        \n        <li>\n            <b>La historia detrás de Microsoft y por qué volvió a ponerse de moda</b><br>\n            <i>Wired ES</i><br>\n            <a href="https://es.wired.com/articulos/la-historia-detras-de-microsoft-y-por-que-volvio-a-ponerse-de-moda">Leer más</a>\n        </li>\n        </ul>'

# %%
from IPython.display import display, HTML

html = generate_newsletter(df, "Risk & Compliance")
display(HTML(html))
# Out:
# <h1>Newsletter – Risk & Compliance</h1><ul>
#         <li>
#             <b>El peligro para la terapia no es la IA: es la ausencia de comunidad</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/el-peligro-para-la-terapia-no-es-la-ia-es-la-ausencia-de-comunidad">Leer más</a>
#         </li>
#
#         <li>
#             <b>Me fui a un retiro con tres personas (humanas) y sus parejas (de IA)</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/me-fui-a-un-retiro-con-tres-personas-humanas-y-sus-parejas-de-ia">Leer más</a>
#         </li>
#
#         <li>
#             <b>La historia de la obsesión de Peter Thiel por el Anticristo</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/la-historia-de-la-obsesion-de-peter-thiel-por-el-anticristo">Leer más</a>
#         </li>
#
#         <li>
#             <b>How Disney Built Star Wars, in real life</b><br>
#             <i>TechCrunch</i><br>
#             <a href="https://techcrunch.com/2019/02/27/how-disney-built-star-wars-in-real-life/">Leer más</a>
#         </li>
#
#         <li>
#             <b>Pepe Aguilar: "La IA no me intimida. Veo con optimismo las oportunidades que ofrece para mi música y mi mensaje"</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/pepe-aguilar-la-ia-no-me-intimida-veo-con-optimismo-las-oportunidades-que-ofrece-para-mi-musica-y-mi-mensaje">Leer más</a>
#         </li>
#
#         <li>
#             <b>Reseña del libro de Yuval Noah Harari,Nexus: Una breve historia de las redes de información desde la Edad de Piedra hasta la IA</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/resena-del-libro-de-yuval-noah-harari-nexus-una-breve-historia-de-las-redes-de-informacion-desde-la-edad-de-piedra-hasta-la-ia">Leer más</a>
#         </li>
#
#         <li>
#             <b>¿Dónde están todos los medicamentos que la IA nos prometió?</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/donde-estan-todos-los-medicamentos-que-la-ia-nos-prometio">Leer más</a>
#         </li>
#
#         <li>
#             <b>Los papás se enamoraron de esta escuela impulsada con IA. Resultó ser una pesadilla</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/los-papas-se-enamoraron-de-esta-escuela-impulsada-con-ia-resulto-ser-una-pesadilla">Leer más</a>
#         </li>
#
#         <li>
#             <b>Strands Agents SDK: A technical deep dive into agent architectures and observability</b><br>
#             <i>AWS Blog</i><br>
#             <a href="https://aws.amazon.com/blogs/machine-learning/strands-agents-sdk-a-technical-deep-dive-into-agent-architectures-and-observability/">Leer más</a>
#         </li>
#
#         <li>
#             <b>La historia detrás de Microsoft y por qué volvió a ponerse de moda</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/la-historia-detras-de-microsoft-y-por-que-volvio-a-ponerse-de-moda">Leer más</a>
#         </li>
#         </ul>

# %%
def generate_newsletter(df_area, area_name):
    html = f"""
    <style>
        body {{ font-family: Arial; }}
        h1 {{ color: #2C3E50; }}
        ul {{ list-style-type: none; padding: 0; }}
        li {{
            margin-bottom: 15px;
            padding: 10px;
            border-left: 4px solid #3498DB;
            background: #F9F9F9;
        }}
        a {{ text-decoration: none; color: #2980B9; }}
        i {{ color: #7F8C8D; }}
    </style>
    <h1>Newsletter – {area_name}</h1>
    <ul>
    """

    for _, row in df_area.sort_values("final_score", ascending=False).head(10).iterrows():
        html += f"""
        <li>
            <b>{row['title']}</b><br>
            <i>{row['source']}</i><br>
            <a href="{row['url']}">Leer más</a>
        </li>
        """

    html += "</ul>"
    return html

# %%
display(HTML(generate_newsletter(df, "Risk & Compliance")))
# Out:
#     <style>
#         body { font-family: Arial; }
#         h1 { color: #2C3E50; }
#         ul { list-style-type: none; padding: 0; }
#         li {
#             margin-bottom: 15px;
#             padding: 10px;
#             border-left: 4px solid #3498DB;
#             background: #F9F9F9;
#         }
#         a { text-decoration: none; color: #2980B9; }
#         i { color: #7F8C8D; }
#     </style>
#     <h1>Newsletter – Risk & Compliance</h1>
#     <ul>
#
#         <li>
#             <b>El peligro para la terapia no es la IA: es la ausencia de comunidad</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/el-peligro-para-la-terapia-no-es-la-ia-es-la-ausencia-de-comunidad">Leer más</a>
#         </li>
#
#         <li>
#             <b>Me fui a un retiro con tres personas (humanas) y sus parejas (de IA)</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/me-fui-a-un-retiro-con-tres-personas-humanas-y-sus-parejas-de-ia">Leer más</a>
#         </li>
#
#         <li>
#             <b>La historia de la obsesión de Peter Thiel por el Anticristo</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/la-historia-de-la-obsesion-de-peter-thiel-por-el-anticristo">Leer más</a>
#         </li>
#
#         <li>
#             <b>How Disney Built Star Wars, in real life</b><br>
#             <i>TechCrunch</i><br>
#             <a href="https://techcrunch.com/2019/02/27/how-disney-built-star-wars-in-real-life/">Leer más</a>
#         </li>
#
#         <li>
#             <b>Pepe Aguilar: "La IA no me intimida. Veo con optimismo las oportunidades que ofrece para mi música y mi mensaje"</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/pepe-aguilar-la-ia-no-me-intimida-veo-con-optimismo-las-oportunidades-que-ofrece-para-mi-musica-y-mi-mensaje">Leer más</a>
#         </li>
#
#         <li>
#             <b>Reseña del libro de Yuval Noah Harari,Nexus: Una breve historia de las redes de información desde la Edad de Piedra hasta la IA</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/resena-del-libro-de-yuval-noah-harari-nexus-una-breve-historia-de-las-redes-de-informacion-desde-la-edad-de-piedra-hasta-la-ia">Leer más</a>
#         </li>
#
#         <li>
#             <b>¿Dónde están todos los medicamentos que la IA nos prometió?</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/donde-estan-todos-los-medicamentos-que-la-ia-nos-prometio">Leer más</a>
#         </li>
#
#         <li>
#             <b>Los papás se enamoraron de esta escuela impulsada con IA. Resultó ser una pesadilla</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/los-papas-se-enamoraron-de-esta-escuela-impulsada-con-ia-resulto-ser-una-pesadilla">Leer más</a>
#         </li>
#
#         <li>
#             <b>Strands Agents SDK: A technical deep dive into agent architectures and observability</b><br>
#             <i>AWS Blog</i><br>
#             <a href="https://aws.amazon.com/blogs/machine-learning/strands-agents-sdk-a-technical-deep-dive-into-agent-architectures-and-observability/">Leer más</a>
#         </li>
#
#         <li>
#             <b>La historia detrás de Microsoft y por qué volvió a ponerse de moda</b><br>
#             <i>Wired ES</i><br>
#             <a href="https://es.wired.com/articulos/la-historia-detras-de-microsoft-y-por-que-volvio-a-ponerse-de-moda">Leer más</a>
#         </li>
#         </ul>

# %%
html = generate_newsletter(df, "Risk & Compliance")

with open("newsletter_data_ai.html", "w", encoding="utf-8") as f:
    f.write(html)

# %%
df.to_pickle("data/processed/even_more_articles.pkl")
